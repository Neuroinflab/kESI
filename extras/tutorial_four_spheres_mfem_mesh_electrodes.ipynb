# %% [markdown]
# Please note that this tutorial assumes you are already familiar
# with technical details of kESI implementation.  If you are not,
# consider running its expanded version
# `tutorial_four_spheres_basics_explained.ipynb` instead.

# %% [markdown]
# # Model
#
# ![four_spheres_3_mm_csf.png](attachment:four_spheres_3_mm_csf.png)
#
# | Volume | Conductivity |
# |:-------|:-------------|
# | Scalp  |  330 mS / m  |
# | Skull  | 16.5 mS / m  |
# | CSF    | 1560 mS / m  |
# | Brain  |  330 mS / m  |

# %% [markdown]
# # Requirements
#
#
# ## Environment
#
# 1. kESI installed normally into a python enviroment.
# 2. Jupyter server to run this notebooc.
# 3. gmsh to generate meshes, installed using pypi or using your favorite installer.
#
#
# ## Setup
#
# ### Mesh
#
# You need to have a mesh in .msh format format. We have prepared 4 spheres mesh templates in air with big grounding plate and in vaccuum with a grounding electrode embedded in the spheres. The meshes have variants with 0.01, 0.005 and 0.005 mm maximum mesh element sizes. To generate MFEM readable mesh out of one of the templates use:
#
#     cd extras/data/bundled/meshes
#     mkdir -p ../../generated/meshes/
#     gmsh -3 four_spheres_in_air_with_plane_0.005.geo -o ../../generated/meshes/four_spheres_in_air_with_plane_0.005.msh
#     cd ../../../
#
# The meshes contain 4 or 5 numbered materials, in order: brain, CSF, skull, scalp, air.

# %% [markdown]
# ### Model properties
#
# We are going to use following material conductivities.
#
# + Brain: 0.33 S/m
# + CSF: 1.65 S/m
# + skull bone: 0.0165 S/m
# + scalp 0.33 S/m
# + air 1e-10 S/m

# %% [markdown]
# ### Electrodes
#
# Lets define positions of three point electrodes:
#
#     NAME,X,Y,Z
#     first,0,0,0.0785
#     second,0.01,0,0.07
#     third,0.01,0.01,0.07
#
# Write the positions as `data/generated/tutorial/four_spheres/tutorial_electrodes.csv`:
#
#    ```
# mkdir -p data/generated/tutorial/four_spheres/
# nano data/generated/tutorial/four_spheres/tutorial_electrodes.csv
# ```

# %% [markdown]
# # Preprocessing
#
# ## Calculation of the leadfield correction
#
# For every electrode we use Finite Element Method (FEM) to calculate the leadfield correction:
#
#     mkdir -p data/generated/tutorial/four_spheres/mfem_leadfield_corrections
#     kesi_mfem_piecewise_solver data/generated/meshes/four_spheres_in_air_with_plane_0.005.msh \
#     data/generated/tutorial/four_spheres/tutorial_electrodes.csv \
#     data/generated/tutorial/four_spheres/mfem_leadfield_corrections \
#     -bp 0 \
#     -c 0.33 1.65 0.0165 0.33 1e-10 \
#     --additional-refinement
#
# This will create a .vtk file which contains the final mesh, leadfield correction and electrode leadfield (assuming electrodes are point charges).
# It's possible to preview the solution with any industry standard viewer, for example `paraview`.

# %% [markdown]
# # Kernel construction tools

# %% [markdown]
# ## Electrode object

# %%
from kesi.kernel.mesh_electrode import read_mesh_electrodes
import pandas as pd

# %%
positions = pd.read_csv("data/generated/tutorial/four_spheres/tutorial_electrodes.csv")[["X", "Y", "Z"]].values
electrodes = read_mesh_electrodes("data/generated/tutorial/four_spheres/mfem_leadfield_corrections/four_spheres_in_air_with_plane_0.005.vtk",
                                       ["first", "second", "third"], positions)
# Out:
# loading electrodes: 3it [00:00,  4.36it/s]

# %% [markdown]
# ## Model source
#
# We want to use CSD basis functions 18mm wide ($R = 9mm$).

# %%
from kesi.common import SphericalSplineSourceKCSD


def get_model_source(radius):
    spline_nodes = [radius / 3, radius]
    spline_polynomial_coefficients = [[1],
                                      [0,
                                       6.75 / radius,
                                       -13.5 / radius ** 2,
                                       6.75 / radius ** 3]]
    return SphericalSplineSourceKCSD(0, 0, 0,
                                     spline_nodes,
                                     spline_polynomial_coefficients)

# %%
SRC_R = 9e-3

model_src = get_model_source(SRC_R)

# %% [markdown]
# ## Convolver object

# %%
import numpy as np

from kesi.kernel.constructor import Convolver

BRAIN_RADIUS = 0.079
ROMBERG_K = 4

_h_min = SRC_R * 2**(1 - ROMBERG_K)
_n_xy = int(np.floor(2 * BRAIN_RADIUS / _h_min)) + 1
_n_z = int(np.floor((BRAIN_RADIUS + SRC_R) / _h_min)) + 1

_X = _Y = np.linspace(-BRAIN_RADIUS, BRAIN_RADIUS, _n_xy)
_Z = np.linspace(-SRC_R, BRAIN_RADIUS, _n_z)

_pot_grid = [_X, _Y, _Z]
_csd_grid = [_X, _Y, _Z[_Z >= 0]]

convolver = Convolver(_pot_grid, _csd_grid)

# %%
BRAIN_RADIUS/_n_xy*2
# Out:
# 0.0011205673758865249

# %% [markdown]
# ## Convolver interface
#
# We include only CSD bases which supports fit in the brain<!--
# and which centroid lies in the upper hemisphere-->.

# %%
from scipy.integrate import romb

from kesi.kernel.constructor import ConvolverInterfaceIndexed


ROMBERG_N = 2**ROMBERG_K + 1
ROMBERG_WEIGHTS = romb(np.identity(ROMBERG_N),
                       dx=2**-ROMBERG_K)

SRC_MASK = ((convolver.SRC_Z > SRC_R - 0.5 * BRAIN_RADIUS)
            & (np.sqrt(np.square(convolver.SRC_X)
                       + np.square(convolver.SRC_Y)
                       + np.square(convolver.SRC_Z)) < BRAIN_RADIUS - SRC_R))

# %%
print(SRC_MASK.sum())
# Out:
# 505703

# %%
convolver_interface = ConvolverInterfaceIndexed(convolver,
                                                model_src.csd,
                                                ROMBERG_WEIGHTS,
                                                SRC_MASK)

# %% [markdown]
# ## Potential Basis Functions object

# %% [markdown]
# ### Potential Basis Functions: analytical solution of the forward problem (kCSD)

# %%
import kesi.kernel.potential_basis_functions as pbf

# %%
pbf_kcsd = pbf.Analytical(convolver_interface,
                          potential=model_src.potential)

# %% [markdown]
# ### Potential Basis Functions: numerically corrected analytical solution of the forward problem (kESI)

# %%
pbf_kesi = pbf.Numerical(convolver_interface)

# %% [markdown]
# ## (Cross)kernel constructors

# %%
from kesi.kernel.constructor import KernelConstructor, CrossKernelConstructor

# %%
kernel_constructor = KernelConstructor()

# %%
CSD_MASK = np.ones(convolver.shape('CSD'),
                   dtype=bool)

# %%
kernel_constructor.crosskernel = CrossKernelConstructor(convolver_interface,
                                                        CSD_MASK)

# %%
def to_3D(CSD):
    return CSD.reshape(convolver.shape('CSD'))

# %% [markdown]
# # kCSD reconstructor

# %% [markdown]
# ## Construction of kernels

# %%
# %%time
B_KCSD = kernel_constructor.potential_basis_functions_at_electrodes(electrodes,
                                                                    pbf_kcsd)
# Out:
# constructing B array: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 184.28it/s]
# CPU times: user 21.8 ms, sys: 880 μs, total: 22.6 ms
# Wall time: 21.9 ms

# %%
KERNEL_KCSD = kernel_constructor.kernel(B_KCSD)

# %%
# %%time
CROSSKERNEL_KCSD = kernel_constructor.crosskernel(B_KCSD)
# Out:
# creating crosskernel per electrode: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 18.99it/s]
# CPU times: user 160 ms, sys: 612 μs, total: 161 ms
# Wall time: 160 ms

# %%
del B_KCSD  # the array is large and no longer needed

# %% [markdown]
# ## Reconstructor object

# %%
from kesi import Reconstructor

# %%
reconstructor_kcsd = Reconstructor(KERNEL_KCSD,
                                   CROSSKERNEL_KCSD)

# %% [markdown]
# # Visualisation

# %%
import matplotlib.pyplot as plt

from local import cbf
from local.tutorial.view import FourSpheres as CoordinatePlanesVisualisation

# %%
csd_plotter = CoordinatePlanesVisualisation(convolver.CSD_GRID,
                                            [0.01, 0, 0.065],
                                            unit_factor= 1e9 * 1e-12,  # m3 to mm3 and Ampares to pikoAmperes
                                            unit='$\\frac{pA}{mm^3}$',
                                            length_factor=1e3,
                                            length_unit='$mm$')

# %% [markdown]
# # Ground Truth CSD and its electric field

# %% [markdown]
# ## GT CSD

# %%
from local.tutorial import eigh


EIGENVALUES_KCSD, EIGENVECTORS_KCSD = eigh(KERNEL_KCSD)

GT_CSD = 10 * to_3D(reconstructor_kcsd(EIGENVECTORS_KCSD[:, 0]))

# %%
from kesi.common import GaussianSourceKCSD3D
GT_m = GaussianSourceKCSD3D(0.025, 0, 0.040, 0.010, conductivity=0.33).csd(*convolver.CSD_GRID)
GT_p = GaussianSourceKCSD3D(0.025, 0, 0.035, 0.010, conductivity=0.33).csd(*convolver.CSD_GRID) * -1
GT_CSD = GT_m + GT_p

# %%
csd_plotter.plot_volume(GT_CSD, 'GT CSD')

# %% [markdown]
# ## FEM forward modelling

# %% [markdown]
# We now use MFEM forward modeling to calculate potential distribution.

# %%
# %%time
from kesi.mfem_solver.forward_solver import CSDForwardSolver
import os

meshfile = os.path.join("data", "generated", "meshes", "four_spheres_in_air_with_plane_0.005.msh")  # 4 spheres in air, with ground
conductivities = np.array([0.33, 1.65, 0.0165, 0.33, 1e-10])  # S/m brain, csf, skull, scalp, air
solver = CSDForwardSolver(meshfile, conductivities)
# Out:
# CPU times: user 82 μs, sys: 27 μs, total: 109 μs
# Wall time: 113 μs

# %%
# %%time
solver.solve(_csd_grid, GT_CSD)
# Out:
# Number of finite element unknowns: 180550
# Size of linear system: 180550
# Average reduction factor = 0.948584
#    Iteration :   0  (B r, r) = 7220.59
#    Iteration :   1  (B r, r) = 3814.68
# saving output mesh
#    Iteration :   2  (B r, r) = 3555.66
#    Iteration :   3  (B r, r) = 2369.51
#    Iteration :   4  (B r, r) = 1618.66
#    Iteration :   5  (B r, r) = 1539.12
#    Iteration :   6  (B r, r) = 1214.81
#    Iteration :   7  (B r, r) = 958.225
#    Iteration :   8  (B r, r) = 851.484
#    Iteration :   9  (B r, r) = 726.703
#    Iteration :  10  (B r, r) = 606.762
#    Iteration :  11  (B r, r) = 512.282
#    Iteration :  12  (B r, r) = 454.64
#    Iteration :  13  (B r, r) = 386.235
#    Iteration :  14  (B r, r) = 333.713
#    Iteration :  15  (B r, r) = 289.671
#    Iteration :  16  (B r, r) = 252.844
#    Iteration :  17  (B r, r) = 231.595
#    Iteration :  18  (B r, r) = 220.374
#    Iteration :  19  (B r, r) = 218.253
#    Iteration :  20  (B r, r) = 208.555
#    Iteration :  21  (B r, r) = 205.012
#    Iteration :  22  (B r, r) = 224.713
#    Iteration :  23  (B r, r) = 235.541
#    Iteration :  24  (B r, r) = 223.245
#    Iteration :  25  (B r, r) = 200.917
#    Iteration :  26  (B r, r) = 198.612
#    Iteration :  27  (B r, r) = 187.226
#    Iteration :  28  (B r, r) = 179.105
#    Iteration :  29  (B r, r) = 183.063
#    Iteration :  30  (B r, r) = 178.062
#    Iteration :  31  (B r, r) = 151.107
#    Iteration :  32  (B r, r) = 129.08
#    Iteration :  33  (B r, r) = 123.318
#    Iteration :  34  (B r, r) = 112.678
#    Iteration :  35  (B r, r) = 100.371
#    Iteration :  36  (B r, r) = 84.9753
#    Iteration :  37  (B r, r) = 65.5177
#    Iteration :  38  (B r, r) = 50.7593
#    Iteration :  39  (B r, r) = 40.9203
#    Iteration :  40  (B r, r) = 30.8067
#    Iteration :  41  (B r, r) = 23.9194
#    Iteration :  42  (B r, r) = 19.187
#    Iteration :  43  (B r, r) = 15.6479
#    Iteration :  44  (B r, r) = 13.9366
#    Iteration :  45  (B r, r) = 12.2796
#    Iteration :  46  (B r, r) = 9.82704
#    Iteration :  47  (B r, r) = 7.2295
#    Iteration :  48  (B r, r) = 5.91512
#    Iteration :  49  (B r, r) = 5.88971
#    Iteration :  50  (B r, r) = 6.28001
#    Iteration :  51  (B r, r) = 5.81269
#    Iteration :  52  (B r, r) = 4.87017
#    Iteration :  53  (B r, r) = 3.97743
#    Iteration :  54  (B r, r) = 3.37912
#    Iteration :  55  (B r, r) = 2.70003
#    Iteration :  56  (B r, r) = 2.17287
#    Iteration :  57  (B r, r) = 1.77874
#    Iteration :  58  (B r, r) = 1.49528
#    Iteration :  59  (B r, r) = 1.25738
#    Iteration :  60  (B r, r) = 1.06119
#    Iteration :  61  (B r, r) = 0.924308
#    Iteration :  62  (B r, r) = 0.88259
#    Iteration :  63  (B r, r) = 0.871673
#    Iteration :  64  (B r, r) = 0.858594
#    Iteration :  65  (B r, r) = 0.753592
#    Iteration :  66  (B r, r) = 0.675259
#    Iteration :  67  (B r, r) = 0.661972
#    Iteration :  68  (B r, r) = 0.675286
#    Iteration :  69  (B r, r) = 0.605869
#    Iteration :  70  (B r, r) = 0.50807
#    Iteration :  71  (B r, r) = 0.443801
#    Iteration :  72  (B r, r) = 0.375835
#    Iteration :  73  (B r, r) = 0.2842
#    Iteration :  74  (B r, r) = 0.218723
#    Iteration :  75  (B r, r) = 0.173611
#    Iteration :  76  (B r, r) = 0.124743
#    Iteration :  77  (B r, r) = 0.0842201
#    Iteration :  78  (B r, r) = 0.0575885
#    Iteration :  79  (B r, r) = 0.0414588
#    Iteration :  80  (B r, r) = 0.0301009
#    Iteration :  81  (B r, r) = 0.0224962
#    Iteration :  82  (B r, r) = 0.0162747
#    Iteration :  83  (B r, r) = 0.0111788
#    Iteration :  84  (B r, r) = 0.00765451
#    Iteration :  85  (B r, r) = 0.00528097
#    Iteration :  86  (B r, r) = 0.00344376
#    Iteration :  87  (B r, r) = 0.00223743
#    Iteration :  88  (B r, r) = 0.00150486
#    Iteration :  89  (B r, r) = 0.00103913
#    Iteration :  90  (B r, r) = 0.000701253
#    Iteration :  91  (B r, r) = 0.000514575
#    Iteration :  92  (B r, r) = 0.00046452
#    Iteration :  93  (B r, r) = 0.000454641
#    Iteration :  94  (B r, r) = 0.000420246
#    Iteration :  95  (B r, r) = 0.000341562
#    Iteration :  96  (B r, r) = 0.000258639
#    Iteration :  97  (B r, r) = 0.000194781
#    Iteration :  98  (B r, r) = 0.000144865
#    Iteration :  99  (B r, r) = 0.000104051
#    Iteration : 100  (B r, r) = 7.87571e-05
#    Iteration : 101  (B r, r) = 6.56144e-05
#    Iteration : 102  (B r, r) = 5.05834e-05
#    Iteration : 103  (B r, r) = 3.41493e-05
#    Iteration : 104  (B r, r) = 2.38264e-05
#    Iteration : 105  (B r, r) = 1.92032e-05
#    Iteration : 106  (B r, r) = 1.61673e-05
#    Iteration : 107  (B r, r) = 1.18364e-05
#    Iteration : 108  (B r, r) = 8.58472e-06
#    Iteration : 109  (B r, r) = 7.05036e-06
#    Iteration : 110  (B r, r) = 6.08228e-06
#    Iteration : 111  (B r, r) = 5.17457e-06
#    Iteration : 112  (B r, r) = 4.61572e-06
#    Iteration : 113  (B r, r) = 4.34189e-06
#    Iteration : 114  (B r, r) = 3.77344e-06
#    Iteration : 115  (B r, r) = 3.30215e-06
#    Iteration : 116  (B r, r) = 3.00486e-06
#    Iteration : 117  (B r, r) = 2.71096e-06
#    Iteration : 118  (B r, r) = 2.49128e-06
#    Iteration : 119  (B r, r) = 2.39514e-06
#    Iteration : 120  (B r, r) = 2.54912e-06
#    Iteration : 121  (B r, r) = 2.88216e-06
#    Iteration : 122  (B r, r) = 3.37709e-06
#    Iteration : 123  (B r, r) = 3.93295e-06
#    Iteration : 124  (B r, r) = 4.48812e-06
#    Iteration : 125  (B r, r) = 5.1e-06
#    Iteration : 126  (B r, r) = 5.95555e-06
#    Iteration : 127  (B r, r) = 7.07201e-06
#    Iteration : 128  (B r, r) = 8.51039e-06
#    Iteration : 129  (B r, r) = 1.13541e-05
#    Iteration : 130  (B r, r) = 1.40557e-05
#    Iteration : 131  (B r, r) = 1.43558e-05
#    Iteration : 132  (B r, r) = 1.32948e-05
#    Iteration : 133  (B r, r) = 1.32311e-05
#    Iteration : 134  (B r, r) = 1.32127e-05
#    Iteration : 135  (B r, r) = 1.32695e-05
#    Iteration : 136  (B r, r) = 1.52946e-05
#    Iteration : 137  (B r, r) = 1.93852e-05
#    Iteration : 138  (B r, r) = 2.3409e-05
#    Iteration : 139  (B r, r) = 2.69493e-05
#    Iteration : 140  (B r, r) = 2.98967e-05
#    Iteration : 141  (B r, r) = 3.34031e-05
#    Iteration : 142  (B r, r) = 3.76542e-05
#    Iteration : 143  (B r, r) = 4.20683e-05
#    Iteration : 144  (B r, r) = 4.25184e-05
#    Iteration : 145  (B r, r) = 4.30327e-05
#    Iteration : 146  (B r, r) = 4.98839e-05
#    Iteration : 147  (B r, r) = 6.38349e-05
#    Iteration : 148  (B r, r) = 8.01319e-05
#    Iteration : 149  (B r, r) = 9.3488e-05
#    Iteration : 150  (B r, r) = 0.000108127
#    Iteration : 151  (B r, r) = 0.000140767
#    Iteration : 152  (B r, r) = 0.000201416
#    Iteration : 153  (B r, r) = 0.00028508
#    Iteration : 154  (B r, r) = 0.000367596
#    Iteration : 155  (B r, r) = 0.000453655
#    Iteration : 156  (B r, r) = 0.000554015
#    Iteration : 157  (B r, r) = 0.000711804
#    Iteration : 158  (B r, r) = 0.000921932
#    Iteration : 159  (B r, r) = 0.00116211
#    Iteration : 160  (B r, r) = 0.00135823
#    Iteration : 161  (B r, r) = 0.00156847
#    Iteration : 162  (B r, r) = 0.00186022
#    Iteration : 163  (B r, r) = 0.00204403
#    Iteration : 164  (B r, r) = 0.00198608
#    Iteration : 165  (B r, r) = 0.00192502
#    Iteration : 166  (B r, r) = 0.00195295
#    Iteration : 167  (B r, r) = 0.00234781
#    Iteration : 168  (B r, r) = 0.00305058
#    Iteration : 169  (B r, r) = 0.00378351
#    Iteration : 170  (B r, r) = 0.00434456
#    Iteration : 171  (B r, r) = 0.00492501
#    Iteration : 172  (B r, r) = 0.00556332
#    Iteration : 173  (B r, r) = 0.00667801
#    Iteration : 174  (B r, r) = 0.00859542
#    Iteration : 175  (B r, r) = 0.0121981
#    Iteration : 176  (B r, r) = 0.0180626
#    Iteration : 177  (B r, r) = 0.0248468
#    Iteration : 178  (B r, r) = 0.0319177
#    Iteration : 179  (B r, r) = 0.0416314
#    Iteration : 180  (B r, r) = 0.0571547
#    Iteration : 181  (B r, r) = 0.0823084
#    Iteration : 182  (B r, r) = 0.114587
#    Iteration : 183  (B r, r) = 0.150146
#    Iteration : 184  (B r, r) = 0.179084
#    Iteration : 185  (B r, r) = 0.20444
#    Iteration : 186  (B r, r) = 0.228252
#    Iteration : 187  (B r, r) = 0.263854
#    Iteration : 188  (B r, r) = 0.321228
#    Iteration : 189  (B r, r) = 0.390371
#    Iteration : 190  (B r, r) = 0.500975
#    Iteration : 191  (B r, r) = 0.724971
#    Iteration : 192  (B r, r) = 1.05434
#    Iteration : 193  (B r, r) = 1.4382
#    Iteration : 194  (B r, r) = 1.88511
#    Iteration : 195  (B r, r) = 2.54063
#    Iteration : 196  (B r, r) = 3.39522
#    Iteration : 197  (B r, r) = 4.29386
#    Iteration : 198  (B r, r) = 5.48531
#    Iteration : 199  (B r, r) = 7.48215
#    Iteration : 200  (B r, r) = 11.0603
#    Iteration : 201  (B r, r) = 17.3142
#    Iteration : 202  (B r, r) = 28.7717
#    Iteration : 203  (B r, r) = 47.2999
#    Iteration : 204  (B r, r) = 73.4617
#    Iteration : 205  (B r, r) = 110.097
#    Iteration : 206  (B r, r) = 157.193
#    Iteration : 207  (B r, r) = 214.449
#    Iteration : 208  (B r, r) = 277.7
#    Iteration : 209  (B r, r) = 365.148
#    Iteration : 210  (B r, r) = 460.839
#    Iteration : 211  (B r, r) = 584.02
#    Iteration : 212  (B r, r) = 753.391
#    Iteration : 213  (B r, r) = 976.318
#    Iteration : 214  (B r, r) = 1262.03
#    Iteration : 215  (B r, r) = 1557.66
#    Iteration : 216  (B r, r) = 1942.59
#    Iteration : 217  (B r, r) = 2316.38
#    Iteration : 218  (B r, r) = 2637.39
#    Iteration : 219  (B r, r) = 2579.58
#    Iteration : 220  (B r, r) = 2218.09
#    Iteration : 221  (B r, r) = 1822.09
#    Iteration : 222  (B r, r) = 1464.67
#    Iteration : 223  (B r, r) = 1179.09
#    Iteration : 224  (B r, r) = 933.36
#    Iteration : 225  (B r, r) = 740.704
#    Iteration : 226  (B r, r) = 629.15
#    Iteration : 227  (B r, r) = 599.006
#    Iteration : 228  (B r, r) = 602.101
#    Iteration : 229  (B r, r) = 594.594
#    Iteration : 230  (B r, r) = 535.886
#    Iteration : 231  (B r, r) = 474.65
#    Iteration : 232  (B r, r) = 403.852
#    Iteration : 233  (B r, r) = 336.721
#    Iteration : 234  (B r, r) = 286.664
#    Iteration : 235  (B r, r) = 243.451
#    Iteration : 236  (B r, r) = 193.824
#    Iteration : 237  (B r, r) = 143.268
#    Iteration : 238  (B r, r) = 110.391
#    Iteration : 239  (B r, r) = 85.0215
#    Iteration : 240  (B r, r) = 63.2972
#    Iteration : 241  (B r, r) = 45.4313
#    Iteration : 242  (B r, r) = 31.7005
#    Iteration : 243  (B r, r) = 21.1095
#    Iteration : 244  (B r, r) = 13.9333
#    Iteration : 245  (B r, r) = 8.83952
#    Iteration : 246  (B r, r) = 5.90607
#    Iteration : 247  (B r, r) = 4.06008
#    Iteration : 248  (B r, r) = 2.97275
#    Iteration : 249  (B r, r) = 2.27481
#    Iteration : 250  (B r, r) = 1.78792
#    Iteration : 251  (B r, r) = 1.34088
#    Iteration : 252  (B r, r) = 0.984721
#    Iteration : 253  (B r, r) = 0.714591
#    Iteration : 254  (B r, r) = 0.485675
#    Iteration : 255  (B r, r) = 0.317846
#    Iteration : 256  (B r, r) = 0.205299
#    Iteration : 257  (B r, r) = 0.128616
#    Iteration : 258  (B r, r) = 0.0790112
#    Iteration : 259  (B r, r) = 0.0500932
#    Iteration : 260  (B r, r) = 0.0326534
#    Iteration : 261  (B r, r) = 0.0206407
#    Iteration : 262  (B r, r) = 0.0136548
#    Iteration : 263  (B r, r) = 0.00947469
#    Iteration : 264  (B r, r) = 0.00700364
#    Iteration : 265  (B r, r) = 0.00572372
#    Iteration : 266  (B r, r) = 0.00470651
#    Iteration : 267  (B r, r) = 0.00381831
#    Iteration : 268  (B r, r) = 0.00311423
#    Iteration : 269  (B r, r) = 0.00254326
#    Iteration : 270  (B r, r) = 0.0020742
#    Iteration : 271  (B r, r) = 0.00160482
#    Iteration : 272  (B r, r) = 0.0012407
#    Iteration : 273  (B r, r) = 0.000971916
#    Iteration : 274  (B r, r) = 0.0007476
#    Iteration : 275  (B r, r) = 0.000593739
#    Iteration : 276  (B r, r) = 0.000418045
#    Iteration : 277  (B r, r) = 0.000263683
#    Iteration : 278  (B r, r) = 0.000161411
#    Iteration : 279  (B r, r) = 9.70316e-05
#    Iteration : 280  (B r, r) = 6.00751e-05
#    Iteration : 281  (B r, r) = 4.07864e-05
#    Iteration : 282  (B r, r) = 3.15962e-05
#    Iteration : 283  (B r, r) = 2.73393e-05
#    Iteration : 284  (B r, r) = 2.38071e-05
#    Iteration : 285  (B r, r) = 2.15419e-05
#    Iteration : 286  (B r, r) = 2.02317e-05
#    Iteration : 287  (B r, r) = 1.82663e-05
#    Iteration : 288  (B r, r) = 1.51518e-05
#    Iteration : 289  (B r, r) = 1.15947e-05
#    Iteration : 290  (B r, r) = 8.95212e-06
#    Iteration : 291  (B r, r) = 7.34273e-06
#    Iteration : 292  (B r, r) = 6.47244e-06
#    Iteration : 293  (B r, r) = 5.53184e-06
#    Iteration : 294  (B r, r) = 4.52588e-06
#    Iteration : 295  (B r, r) = 3.6209e-06
#    Iteration : 296  (B r, r) = 2.72831e-06
#    Iteration : 297  (B r, r) = 1.85218e-06
#    Iteration : 298  (B r, r) = 1.19957e-06
#    Iteration : 299  (B r, r) = 7.28738e-07
#    Iteration : 300  (B r, r) = 4.58234e-07
#    Iteration : 301  (B r, r) = 2.95472e-07
#    Iteration : 302  (B r, r) = 1.99351e-07
#    Iteration : 303  (B r, r) = 1.42033e-07
#    Iteration : 304  (B r, r) = 1.0512e-07
#    Iteration : 305  (B r, r) = 7.90611e-08
#    Iteration : 306  (B r, r) = 5.76196e-08
#    Iteration : 307  (B r, r) = 4.18251e-08
#    Iteration : 308  (B r, r) = 3.18038e-08
#    Iteration : 309  (B r, r) = 2.57213e-08
#    Iteration : 310  (B r, r) = 2.31475e-08
#    Iteration : 311  (B r, r) = 2.13105e-08
#    Iteration : 312  (B r, r) = 1.93121e-08
#    Iteration : 313  (B r, r) = 1.66963e-08
#    Iteration : 314  (B r, r) = 1.33593e-08
#    Iteration : 315  (B r, r) = 1.01357e-08
#    Iteration : 316  (B r, r) = 7.60764e-09
#    Iteration : 317  (B r, r) = 5.7488e-09
# saving mesh data scalars pot: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 180550/180550 [00:00<00:00, 955233.71it/s]
# CPU times: user 9.5 s, sys: 63.7 ms, total: 9.56 s
# Wall time: 9.54 s
# <mfem._ser.gridfunc.GridFunction; proxy of <Swig Object of type 'mfem::GridFunction *' at 0x777915ab5b30> >

# %%
potential_plotter = CoordinatePlanesVisualisation(convolver.CSD_GRID,
                                                  [0.01, 0, 0.065],
                                                  unit_factor=1e6,
                                                  unit='$\mu{}V$',
                                                  length_factor=1e3,
                                                  length_unit='$mm$',
                                                  cmap=cbf.PRGn)

# %%
# %%time
potential_plotter.plot_function_vectorized(solver.sample_solution, 'POTENTIAL')
# Out:
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:00<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:00<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:00<00:00]
# CPU times: user 174 ms, sys: 26.2 ms, total: 200 ms
# Wall time: 174 ms

# %% [markdown]
# We probe the potential at electrodes.

# %%
GT_V = np.array([solver.sample_solution_probe(_e.x, _e.y, _e.z) for _e in electrodes])
# Out:
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:00<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:00<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:00<00:00]

# %%
GT_V
# Out:
# array([-27029590.63223677, -27029590.25805711, -27029590.35693935])

# %% [markdown]
# # Reconstruction

# %% [markdown]
# ## kCSD

# %%
CSD_KCSD = to_3D(reconstructor_kcsd(GT_V))

# %%
csd_plotter.compare_with_gt(GT_CSD,
                            CSD_KCSD,
                            'kCSD')

# %% [markdown]
# The reconstruction is mostly error.

# %%
del CSD_KCSD  # the array is large and no longer needed

# %%
del reconstructor_kcsd, CROSSKERNEL_KCSD  # these objects are large and no longer needed

# %% [markdown]
# ## kESI

# %%
# %%time
B_KESI = kernel_constructor.potential_basis_functions_at_electrodes(electrodes,
                                                                    pbf_kesi)
# Out:
# constructing B array:   0%|                                                                                                                                                                                                                              | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                                                                                                                                                                                                 [00:00<?]
# Resampling array Data from a Passed Mesh onto Mesh:   0%|                                                                                                                                                                                                             [00:00<?]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:02<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:02<00:00]
# constructing B array:  33%|███████████████████████████████████████████████████████████████████████▎                                                                                                                                              | 1/3 [00:02<00:05,  2.77s/it]
#   0%|                                                                                                                                                                                                                                                                 [00:00<?]
# Resampling array Data from a Passed Mesh onto Mesh:   0%|                                                                                                                                                                                                             [00:00<?]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:02<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:02<00:00]
# constructing B array:  67%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                       | 2/3 [00:05<00:02,  2.78s/it]
#   0%|                                                                                                                                                                                                                                                                 [00:00<?]
# Resampling array Data from a Passed Mesh onto Mesh:   0%|                                                                                                                                                                                                             [00:00<?]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:02<00:00]
# Resampling array Data from a Passed Mesh onto Mesh: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████[00:02<00:00]
# constructing B array: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:08<00:00,  2.78s/it]
# CPU times: user 8.05 s, sys: 327 ms, total: 8.38 s
# Wall time: 8.35 s

# %% [markdown]
# It may take more than a minute.

# %%
KERNEL_KESI = kernel_constructor.kernel(B_KESI)

# %%
# %%time
CROSSKERNEL_KESI = kernel_constructor.crosskernel(B_KESI)
# Out:
# creating crosskernel per electrode: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 18.91it/s]
# CPU times: user 161 ms, sys: 694 μs, total: 162 ms
# Wall time: 161 ms

# %%
del B_KESI  # the array is large and no longer needed

# %%
reconstructor_kesi = Reconstructor(KERNEL_KESI,
                                   CROSSKERNEL_KESI)

# %%
CSD_KESI = to_3D(reconstructor_kesi(GT_V))

# %%
csd_plotter.compare_with_gt(GT_CSD,
                            CSD_KESI,
                            'kESI')

# %% [markdown]
# The reconstruction is much closer to the ground truth.
# Note that kESI may be at a disadvantage, as the ground
# truth CSD is an eigensource of kCSD.

# %%
del CSD_KESI  # the array is large and no longer needed

# %% [markdown]
# ## Noise
#
# As no real-world measurement is perfect, we introduce
# 2% noise to test how kESI deals with it.

# %%
np.random.seed(42)

V_WITH_NOISE = np.random.normal(loc=GT_V,
                                scale=0.02*np.sqrt(np.square(GT_V).mean()))

# %%
CSD_KESI_WITH_NOISE = to_3D(reconstructor_kesi(V_WITH_NOISE))

# %%
csd_plotter.compare_with_gt(GT_CSD,
                            CSD_KESI_WITH_NOISE,
                            'kESI (noise)')

# %%
del CSD_KESI_WITH_NOISE  # the array is large and no longer needed

# %% [markdown]
# The quality of reconstruction decreased significatntly.

# %% [markdown]
# ## Regularization

# %%
EIGENVALUES_KESI, _ = eigh(KERNEL_KESI)

# %%
plt.plot(EIGENVALUES_KESI,
         marker='o')

plt.yscale('log')

# %%
REGULARIZATION_PARAMETERS = np.logspace(5, 22, 8 * 10 + 1)

assert REGULARIZATION_PARAMETERS.min() <= EIGENVALUES_KESI.min()
assert EIGENVALUES_KESI.max() <= REGULARIZATION_PARAMETERS.max()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[170], line 3
#       1 REGULARIZATION_PARAMETERS = np.logspace(5, 22, 8 * 10 + 1)
# ----> 3 assert REGULARIZATION_PARAMETERS.min() <= EIGENVALUES_KESI.min()
#       4 assert EIGENVALUES_KESI.max() <= REGULARIZATION_PARAMETERS.max()
#
# AssertionError:

# %% [markdown]
# ### Leave-one-out cross-validation

# %%
from kesi.common import cv

# %%
# %%time
CV_ERRORS = cv(reconstructor_kesi, V_WITH_NOISE, REGULARIZATION_PARAMETERS)
# Out:
# CPU times: user 22.9 ms, sys: 3.96 ms, total: 26.9 ms
# Wall time: 21.4 ms

# %%
regularization_parameter_idx = np.argmin(CV_ERRORS)
regularization_parameter = REGULARIZATION_PARAMETERS[regularization_parameter_idx]

# %%
plt.plot(REGULARIZATION_PARAMETERS,
         CV_ERRORS,
         color=cbf.BLUE)
plt.plot(regularization_parameter,
         min(CV_ERRORS),
         marker="o",
         color=cbf.BLUE)
plt.axvspan(EIGENVALUES_KESI.min(),
            EIGENVALUES_KESI.max(),
            ls=":",
            color=cbf.GREEN,
            hatch=".....",
            fill=False)
plt.xlabel('regularization parameter')
plt.xscale('log')
plt.ylabel('L2 norm of cross-validation error')
plt.yscale('log')

# %%
CSD_KESI_CV = to_3D(reconstructor_kesi(V_WITH_NOISE, regularization_parameter))

# %%
csd_plotter.compare_with_gt(GT_CSD,
                            CSD_KESI_CV,
                            'kESI (noise)')

# %%
del CSD_KESI_CV  # the array is large and no longer needed

# %% [markdown]
# ### L-curve

# %%
from local.tutorial.view import LCurvePlotter


plot_lcurve = LCurvePlotter(REGULARIZATION_PARAMETERS)
plot_lcurve(KERNEL_KESI, V_WITH_NOISE,
            cv_selected_parameter=regularization_parameter)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[178], line 5
#       1 from local.tutorial.view import LCurvePlotter
#       4 plot_lcurve = LCurvePlotter(REGULARIZATION_PARAMETERS)
# ----> 5 plot_lcurve(KERNEL_KESI, V_WITH_NOISE,
#       6             cv_selected_parameter=regularization_parameter)
#
# File ~/projects/halje_data_analysis/kESI/extras/local/tutorial/view.py:306, in LCurvePlotter.__call__(self, kernel, measured, cv_selected_parameter, horizontal_offset)
#     304 self._horizontal_offset = horizontal_offset
#     305 self._calculate_curve()
# --> 306 self._set_bbox()
#     307 self._plot_whole_curve()
#     308 self._plot_cropped_curve(cv_selected_parameter)
#
# File ~/projects/halje_data_analysis/kESI/extras/local/tutorial/view.py:327, in LCurvePlotter._set_bbox(self)
#     325 eigenvalues = np.linalg.eigvalsh(self._kernel)
#     326 i_low, i_high = self._get_idx([eigenvalues.min(), eigenvalues.max()])
# --> 327 self._bottom = self._solution_norm[i_high]
#     328 self._top = self._solution_norm[i_low]
#     329 self._left = self._prediction_error[i_low]
#
# IndexError: tuple index out of range
